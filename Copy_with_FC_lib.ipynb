# %%
from os.path import join as pjoin
import tqdm
import pandas as pd
import numpy as np
import os

import time 
import torch
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
import torch.optim as optim
from sklearn.model_selection import train_test_split
import gc
import torchmetrics
import matplotlib.pyplot as plt
from  torch.optim.lr_scheduler import ReduceLROnPlateau
from torchmetrics.classification import MulticlassAccuracy, MulticlassF1Score, MulticlassPrecision, MulticlassRecall

from sklearn.model_selection import GridSearchCV

from copy_from_webp import *

# %%
label_map = {
             'abraham_grampa_simpson': 0,
             'agnes_skinner': 1,
             'apu_nahasapeemapetilon': 2,
             'barney_gumble': 3,
             'bart_simpson': 4,
             'carl_carlson': 5,
             'charles_montgomery_burns': 6,
             'chief_wiggum': 7,
             'cletus_spuckler': 8,
             'comic_book_guy': 9,
             'disco_stu': 10,
             'edna_krabappel': 11,
             'fat_tony': 12,
             'gil': 13,
             'groundskeeper_willie': 14,
             'homer_simpson': 15,
             'kent_brockman': 16,
             'krusty_the_clown': 17,
             'lenny_leonard': 18,
             'lionel_hutz': 19,
             'lisa_simpson': 20,
             'maggie_simpson': 21,
             'marge_simpson': 22,
             'martin_prince': 23,
             'mayor_quimby': 24,
             'milhouse_van_houten': 25,
             'miss_hoover': 26,
             'moe_szyslak': 27,
             'ned_flanders': 28,
             'nelson_muntz': 29,
             'otto_mann': 30,
             'patty_bouvier': 31,
             'principal_skinner': 32,
             'professor_john_frink': 33,
             'rainier_wolfcastle': 34,
             'ralph_wiggum': 35,
             'selma_bouvier': 36,
             'sideshow_bob': 37,
             'sideshow_mel': 38,
             'snake_jailbird': 39,
             'troy_mcclure': 40,
             'waylon_smithers': 41
             }

class Simpson_Train_Dataset(torch.utils.data.Dataset):
    def __init__(self, annotations_file, transform=None):
        self.image_paths = []
        self.bboxes = []
        self.labels = []
        with open(annotations_file, 'r') as f:
            for line in f:
                image_path, x1, y1, x2, y2, label = line.strip().split(',')
                image_path = os.path.join('/kaggle/input/simpsons', image_path)
                if os.path.exists(image_path):
                    self.image_paths.append(image_path)
                    self.bboxes.append([int(x1), int(y1), int(x2), int(y2)])
                    self.labels.append(label)
                    self.bbox = torch.tensor(self.bboxes)
                #else:
                    #print('Не существует файла. Путь:', image_path)
        self.transform = transform
        
    def __len__(self):
        return len(self.image_paths)
    
    def __getitem__(self, index):
        image_path = self.image_paths[index]
        label = self.labels[index]
        bbox = self.bboxes[index]
        image = Image.open(image_path)
        if self.transform:
            image = self.transform(image)
        label = label_map[self.labels[index]]
        return image, label, bbox


class Simpson_Test_Dataset(torch.utils.data.Dataset):
    def __init__(self, data_folder, transform=None):
        self.image_paths = []
        for image_filename in os.listdir(data_folder):
            if os.path.isfile(os.path.join(data_folder, image_filename)):
                self.image_paths.append(os.path.join(data_folder, image_filename))
        self.transform = transform
        
    def __len__(self):
        return len(self.image_paths)
    
    def __getitem__(self, index):
        image_path = self.image_paths[index]
        image = Image.open(image_path)
        
        if self.transform:
            image = self.transform(image)

        label = os.path.basename(image_path)
        label = '_'.join(label.split('_')[:-1])
        label = label_map[label]
        return image, label

# %%
size_image = 128
MEAN_IMAGE_TRANSFORM = [0.4363, 0.4328, 0.3291]
MEAN_IMAGE_STD = [0.2129, 0.2075, 0.2038]

train_transform = transforms.Compose([
    transforms.Resize((size_image, size_image)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(degrees = 90),
    transforms.ToTensor(),
    transforms.Normalize(torch.Tensor(MEAN_IMAGE_TRANSFORM),
                         torch.Tensor(MEAN_IMAGE_STD))
])
test_transform = transforms.Compose([
    transforms.Resize((size_image, size_image)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(degrees = 90),
    transforms.ToTensor(),
    transforms.Normalize(torch.Tensor(MEAN_IMAGE_TRANSFORM),
                         torch.Tensor(MEAN_IMAGE_STD))
])

data_set = Simpson_Train_Dataset('/kaggle/input/simpsons/annotation.txt', transform=train_transform)
test_data = Simpson_Test_Dataset('/kaggle/input/simpsons/test', transform=test_transform)

train_data, val_data = train_test_split(data_set, test_size=0.2, shuffle=True)

# %%
batch_size = 256
train_loader = torch.utils.data.DataLoader(train_data, shuffle=True, batch_size=batch_size, 
                                         num_workers=0, drop_last=True)

val_loader = torch.utils.data.DataLoader(val_data, shuffle=True, batch_size=batch_size, 
                                         num_workers=0, drop_last=True)

test_loader = torch.utils.data.DataLoader(test_data, shuffle=False, batch_size=batch_size, 
                                           num_workers=0, drop_last=False)

# %%
#That's place, there I would like to add realisation from Kagle

# %%
class SimpsonsCNN(nn.Module):
    def __init__(self):
        super(SimpsonsCNN, self).__init__()

        self.conv1 = nn.Sequential( FusedConvBN(3, 16, kernel_size=3), nn.ReLU(),
                                    nn.MaxPool2d(kernel_size=2, stride=2),
                                    FusedConvBN(16, 32, kernel_size=3), 
                                    nn.BatchNorm2d(32), nn.ReLU(), nn.MaxPool2d(kernel_size=2, stride=2), 
                                    nn.Dropout(0.5))
        
        self.conv2 = nn.Sequential( FusedConvBN(32, 32, kernel_size=3), nn.ReLU(),
                                    nn.MaxPool2d(kernel_size=2, stride=2),
                                    FusedConvBN(32, 32, kernel_size=3), 
                                    nn.ReLU(),  nn.MaxPool2d(kernel_size=2, stride=2), 
                                    nn.Dropout(0.5))
        
        self.conv3 = nn.Sequential( FusedConvBN(32, 64, kernel_size=3), nn.ReLU(),
                                    nn.MaxPool2d(kernel_size=2, stride=2),
                                    FusedConvBN(64, 128, kernel_size=3), 
                                    nn.ReLU(), nn.MaxPool2d(kernel_size=2, stride=2), 
                                    nn.Dropout(0.5))
        
        self.conv4 = nn.Sequential( FusedConvBN(128, 256, kernel_size=3), nn.ReLU(),
                                    nn.MaxPool2d(kernel_size=2, stride=2),
                                    FusedConvBN(256, 256, kernel_size=3), 
                                    nn.ReLU(), nn.MaxPool2d(kernel_size=2, stride=2), 
                                    nn.Dropout(0.5))

        self.AApool = nn.AdaptiveAvgPool2d((1,1))
        self.fc1 = nn.Linear( 2 * 128, 1024)
        self.fc2 = nn.Linear(1024, 512)
        self.fc3 = nn.Linear(512, 42)
        self.Mpool = nn.MaxPool2d(kernel_size=2, stride=2)
        
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.AApool(x)
        x = x.view(-1, 2 * 128)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = SimpsonsCNN()
print(count_parameters(model))
criterion = nn.CrossEntropyLoss()
model = model.to(device)
criterion = criterion.to(device)
# Out:
# 1809946

# %%
def valid_map(loader):
    classes = label_map
    classes_amount = len(label_map)
    recall = MulticlassRecall(num_classes=classes_amount, average=None)
    precision = MulticlassPrecision(num_classes=classes_amount, average=None)
    recall.to(device)
    precision.to(device)
    valid_acc = 0
    N = 0
    with torch.no_grad():
        my_loss = 0
        model.eval()
        correct = 0
        total = 0
        for sample in loader:
            images = sample[0]
            labels = sample[1]
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            recall.update(outputs, labels)
            precision.update(outputs, labels)
            _, pred = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (pred == labels).sum().item()
            my_loss += criterion(outputs, labels).item()
            N += 1
        valid_acc = 100 * correct / total
        avr_loss = my_loss/N
    
    return avr_loss, valid_acc, recall, precision

# %%
learning_rate = 0.0013
weight_decay = 0.0005
optimizer = optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), weight_decay = weight_decay)
scheduler = ReduceLROnPlateau(optimizer, 'min')
#scaler = torch.cuda.amp.GradScaler()
torch.cuda.empty_cache()
gc.collect()
list_loss = []
num_epochs = 100

learn_transform = transforms.Compose([ 
    transforms.RandomHorizontalFlip(), 
    transforms.RandomRotation(degrees = 90)
])

print(f'-----------------------------Learning begin, total of {num_epochs} epochs----------------------------\n')
for epoch in range(num_epochs):
    correct, total = 0, 0
    
    avr_loss, val_acc, val_rec, val_prec = valid_map(val_loader)
    val_rec = sum(val_rec.compute())/len(list(label_map))
    val_prec = sum(val_prec.compute())/len(list(label_map))
    print(f'\n-------------------------------------Result of Epoch {epoch}------------------------------------')
    print(f'Valid_Loss: {avr_loss:.4f}, Valid_accuracy: {val_acc:.2f}%, Valid Recall: {100*val_rec.item():.2f}%, Valid Precision: {100*val_prec.item():.2f}%')
    print(f'-------------------------------------------------------------------------------------------\n')
    
    if val_acc > 85:
        break
        
    model.train()
    
    train_loader = torch.utils.data.DataLoader(train_data, shuffle=True, batch_size=batch_size, 
                                         num_workers=0, drop_last=True)
    
    for i, (img, labels, _) in enumerate(train_loader):
        img = img.to(device)
        labels = labels.to(device)
        optimizer.zero_grad()
        img = learn_transform(img)

        with torch.cuda.amp.autocast(enabled=True):
            pred = model(img)
            loss = criterion(pred, labels)
            _, pred1 = torch.max(pred.data, 1)
        
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
    
        torch.cuda.empty_cache()
        gc.collect()
        list_loss.append(loss.item())
        correct += (pred1 == labels).sum().item()
        total += labels.size(0)
        # scheduler.step(loss, epoch) # lr
        if (i + 1) % 10 == 0:
            train_acc = 100 * correct / total
            correct, total = 0, 0
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_loader)}], Loss: {loss.item():.4f}, Acc: {train_acc:.2f}%')
# Out:
# -----------------------------Learning begin, total of 100 epochs----------------------------
#
#
# -------------------------------------Result of Epoch 0------------------------------------
# Valid_Loss: 3.7353, Valid_accuracy: 2.95%, Valid Recall: 2.38%, Valid Precision: 0.07%
# -------------------------------------------------------------------------------------------
#
# Epoch [1/100], Step [10/37], Loss: 2.6929, Acc: 11.25%
# Epoch [1/100], Step [20/37], Loss: 2.6661, Acc: 15.62%
# Epoch [1/100], Step [30/37], Loss: 2.4160, Acc: 20.47%
#
# -------------------------------------Result of Epoch 1------------------------------------
# Valid_Loss: 2.7750, Valid_accuracy: 20.31%, Valid Recall: 5.44%, Valid Precision: 3.91%
# -------------------------------------------------------------------------------------------
#
# Epoch [2/100], Step [10/37], Loss: 2.4514, Acc: 25.70%
# Epoch [2/100], Step [20/37], Loss: 2.2401, Acc: 26.95%
# Epoch [2/100], Step [30/37], Loss: 2.1819, Acc: 26.25%
#
# -------------------------------------Result of Epoch 2------------------------------------
# Valid_Loss: 2.3438, Valid_accuracy: 26.04%, Valid Recall: 8.14%, Valid Precision: 9.50%
# -------------------------------------------------------------------------------------------
#
# Epoch [3/100], Step [10/37], Loss: 2.2108, Acc: 30.23%
# Epoch [3/100], Step [20/37], Loss: 2.1462, Acc: 33.75%
# Epoch [3/100], Step [30/37], Loss: 2.3444, Acc: 33.28%
#
# -------------------------------------Result of Epoch 3------------------------------------
# Valid_Loss: 2.6979, Valid_accuracy: 22.14%, Valid Recall: 6.70%, Valid Precision: 8.83%
# -------------------------------------------------------------------------------------------
#
# Epoch [4/100], Step [10/37], Loss: 2.0250, Acc: 35.08%
# Epoch [4/100], Step [20/37], Loss: 1.7954, Acc: 37.27%
# Epoch [4/100], Step [30/37], Loss: 1.9403, Acc: 37.42%
#
# -------------------------------------Result of Epoch 4------------------------------------
# Valid_Loss: 2.1423, Valid_accuracy: 33.25%, Valid Recall: 10.47%, Valid Precision: 12.85%
# -------------------------------------------------------------------------------------------
#
# Epoch [5/100], Step [10/37], Loss: 1.8598, Acc: 40.23%
# Epoch [5/100], Step [20/37], Loss: 1.6966, Acc: 43.12%
# Epoch [5/100], Step [30/37], Loss: 1.7495, Acc: 41.72%
#
# -------------------------------------Result of Epoch 5------------------------------------
# Valid_Loss: 2.0789, Valid_accuracy: 35.85%, Valid Recall: 11.74%, Valid Precision: 14.66%
# -------------------------------------------------------------------------------------------
#
# Epoch [6/100], Step [10/37], Loss: 1.7574, Acc: 45.39%
# Epoch [6/100], Step [20/37], Loss: 1.7822, Acc: 43.44%
# Epoch [6/100], Step [30/37], Loss: 1.6333, Acc: 46.33%
#
# -------------------------------------Result of Epoch 6------------------------------------
# Valid_Loss: 1.8751, Valid_accuracy: 42.45%, Valid Recall: 14.96%, Valid Precision: 14.90%
# -------------------------------------------------------------------------------------------
#
# Epoch [7/100], Step [10/37], Loss: 1.4895, Acc: 46.33%
# Epoch [7/100], Step [20/37], Loss: 1.9042, Acc: 47.11%
# Epoch [7/100], Step [30/37], Loss: 1.6339, Acc: 48.20%
#
# -------------------------------------Result of Epoch 7------------------------------------
# Valid_Loss: 2.1900, Valid_accuracy: 37.93%, Valid Recall: 12.91%, Valid Precision: 21.22%
# -------------------------------------------------------------------------------------------
#
# Epoch [8/100], Step [10/37], Loss: 1.7063, Acc: 49.92%
# Epoch [8/100], Step [20/37], Loss: 1.6935, Acc: 46.88%
# Epoch [8/100], Step [30/37], Loss: 1.6136, Acc: 47.50%
#
# -------------------------------------Result of Epoch 8------------------------------------
# Valid_Loss: 1.7353, Valid_accuracy: 47.83%, Valid Recall: 16.74%, Valid Precision: 21.67%
# -------------------------------------------------------------------------------------------
#
# Epoch [9/100], Step [10/37], Loss: 1.5209, Acc: 49.14%
# Epoch [9/100], Step [20/37], Loss: 1.6201, Acc: 51.09%
# Epoch [9/100], Step [30/37], Loss: 1.4194, Acc: 50.70%
#
# -------------------------------------Result of Epoch 9------------------------------------
# Valid_Loss: 1.6603, Valid_accuracy: 47.66%, Valid Recall: 16.29%, Valid Precision: 22.10%
# -------------------------------------------------------------------------------------------
#
# Epoch [10/100], Step [10/37], Loss: 1.2984, Acc: 52.11%
# Epoch [10/100], Step [20/37], Loss: 1.4699, Acc: 51.17%
# Epoch [10/100], Step [30/37], Loss: 1.5313, Acc: 50.39%
#
# -------------------------------------Result of Epoch 10------------------------------------
# Valid_Loss: 1.5539, Valid_accuracy: 51.65%, Valid Recall: 19.17%, Valid Precision: 20.54%
# -------------------------------------------------------------------------------------------
#
# Epoch [11/100], Step [10/37], Loss: 1.3749, Acc: 52.58%
# Epoch [11/100], Step [20/37], Loss: 1.4840, Acc: 53.36%
# Epoch [11/100], Step [30/37], Loss: 1.4740, Acc: 52.58%
#
# -------------------------------------Result of Epoch 11------------------------------------
# Valid_Loss: 1.5961, Valid_accuracy: 49.22%, Valid Recall: 17.54%, Valid Precision: 20.86%
# -------------------------------------------------------------------------------------------
#
# Epoch [12/100], Step [10/37], Loss: 1.5045, Acc: 55.08%
# Epoch [12/100], Step [20/37], Loss: 1.3720, Acc: 55.86%
# Epoch [12/100], Step [30/37], Loss: 1.4286, Acc: 57.58%
#
# -------------------------------------Result of Epoch 12------------------------------------
# Valid_Loss: 1.7199, Valid_accuracy: 45.14%, Valid Recall: 16.26%, Valid Precision: 18.90%
# -------------------------------------------------------------------------------------------
#
# Epoch [13/100], Step [10/37], Loss: 1.3692, Acc: 56.02%
# Epoch [13/100], Step [20/37], Loss: 1.0303, Acc: 60.08%
# Epoch [13/100], Step [30/37], Loss: 1.4455, Acc: 54.69%
#
# -------------------------------------Result of Epoch 13------------------------------------
# Valid_Loss: 1.4247, Valid_accuracy: 54.43%, Valid Recall: 20.98%, Valid Precision: 24.10%
# -------------------------------------------------------------------------------------------
#
# Epoch [14/100], Step [10/37], Loss: 1.2251, Acc: 59.38%
# Epoch [14/100], Step [20/37], Loss: 1.3680, Acc: 59.92%
# Epoch [14/100], Step [30/37], Loss: 1.3263, Acc: 58.20%
#
# -------------------------------------Result of Epoch 14------------------------------------
# Valid_Loss: 1.4725, Valid_accuracy: 54.43%, Valid Recall: 20.15%, Valid Precision: 22.89%
# -------------------------------------------------------------------------------------------
#
# Epoch [15/100], Step [10/37], Loss: 1.3058, Acc: 60.23%
# Epoch [15/100], Step [20/37], Loss: 1.2237, Acc: 60.55%
# Epoch [15/100], Step [30/37], Loss: 1.1867, Acc: 59.92%
#
# -------------------------------------Result of Epoch 15------------------------------------
# Valid_Loss: 1.3862, Valid_accuracy: 55.82%, Valid Recall: 22.63%, Valid Precision: 27.70%
# -------------------------------------------------------------------------------------------
#
# Epoch [16/100], Step [10/37], Loss: 1.0115, Acc: 59.92%
# Epoch [16/100], Step [20/37], Loss: 1.2733, Acc: 60.62%
# Epoch [16/100], Step [30/37], Loss: 1.3001, Acc: 60.55%
#
# -------------------------------------Result of Epoch 16------------------------------------
# Valid_Loss: 1.2549, Valid_accuracy: 61.11%, Valid Recall: 23.06%, Valid Precision: 29.54%
# -------------------------------------------------------------------------------------------
#
# Epoch [17/100], Step [10/37], Loss: 1.4662, Acc: 62.73%
# Epoch [17/100], Step [20/37], Loss: 1.3709, Acc: 62.66%
# Epoch [17/100], Step [30/37], Loss: 1.3033, Acc: 61.48%
#
# -------------------------------------Result of Epoch 17------------------------------------
# Valid_Loss: 1.3644, Valid_accuracy: 57.64%, Valid Recall: 22.15%, Valid Precision: 25.20%
# -------------------------------------------------------------------------------------------
#
# Epoch [18/100], Step [10/37], Loss: 1.2726, Acc: 59.77%
# Epoch [18/100], Step [20/37], Loss: 0.9937, Acc: 66.25%
# Epoch [18/100], Step [30/37], Loss: 1.2381, Acc: 61.56%
#
# -------------------------------------Result of Epoch 18------------------------------------
# Valid_Loss: 1.1875, Valid_accuracy: 63.54%, Valid Recall: 26.18%, Valid Precision: 27.94%
# -------------------------------------------------------------------------------------------
#
# Epoch [19/100], Step [10/37], Loss: 1.0741, Acc: 63.36%
# Epoch [19/100], Step [20/37], Loss: 1.0749, Acc: 65.94%
# Epoch [19/100], Step [30/37], Loss: 1.3802, Acc: 63.52%
#
# -------------------------------------Result of Epoch 19------------------------------------
# Valid_Loss: 1.2000, Valid_accuracy: 60.16%, Valid Recall: 23.56%, Valid Precision: 28.60%
# -------------------------------------------------------------------------------------------
#
# Epoch [20/100], Step [10/37], Loss: 1.0438, Acc: 67.27%
# Epoch [20/100], Step [20/37], Loss: 1.0431, Acc: 63.91%
# Epoch [20/100], Step [30/37], Loss: 1.1416, Acc: 63.83%
#
# -------------------------------------Result of Epoch 20------------------------------------
# Valid_Loss: 1.2467, Valid_accuracy: 62.85%, Valid Recall: 25.34%, Valid Precision: 26.96%
# -------------------------------------------------------------------------------------------
#
# Epoch [21/100], Step [10/37], Loss: 1.0123, Acc: 67.19%
# Epoch [21/100], Step [20/37], Loss: 1.0936, Acc: 66.64%
# Epoch [21/100], Step [30/37], Loss: 0.9679, Acc: 63.67%
#
# -------------------------------------Result of Epoch 21------------------------------------
# Valid_Loss: 1.2883, Valid_accuracy: 58.85%, Valid Recall: 23.20%, Valid Precision: 25.43%
# -------------------------------------------------------------------------------------------
#
# Epoch [22/100], Step [10/37], Loss: 1.2136, Acc: 66.64%
# Epoch [22/100], Step [20/37], Loss: 0.9687, Acc: 67.50%
# Epoch [22/100], Step [30/37], Loss: 1.2391, Acc: 64.30%
#
# -------------------------------------Result of Epoch 22------------------------------------
# Valid_Loss: 1.1225, Valid_accuracy: 65.89%, Valid Recall: 26.45%, Valid Precision: 28.25%
# -------------------------------------------------------------------------------------------
#
# Epoch [23/100], Step [10/37], Loss: 0.8960, Acc: 67.81%
# Epoch [23/100], Step [20/37], Loss: 1.1618, Acc: 66.09%
# Epoch [23/100], Step [30/37], Loss: 1.1646, Acc: 66.17%
#
# -------------------------------------Result of Epoch 23------------------------------------
# Valid_Loss: 0.9993, Valid_accuracy: 69.36%, Valid Recall: 27.80%, Valid Precision: 29.54%
# -------------------------------------------------------------------------------------------
#
# Epoch [24/100], Step [10/37], Loss: 1.0393, Acc: 70.31%
# Epoch [24/100], Step [20/37], Loss: 0.9973, Acc: 66.02%
# Epoch [24/100], Step [30/37], Loss: 1.1640, Acc: 68.98%
#
# -------------------------------------Result of Epoch 24------------------------------------
# Valid_Loss: 1.0310, Valid_accuracy: 68.66%, Valid Recall: 27.95%, Valid Precision: 30.09%
# -------------------------------------------------------------------------------------------
#
# Epoch [25/100], Step [10/37], Loss: 1.1124, Acc: 66.64%
# Epoch [25/100], Step [20/37], Loss: 0.9601, Acc: 66.25%
# Epoch [25/100], Step [30/37], Loss: 1.2668, Acc: 70.00%
#
# -------------------------------------Result of Epoch 25------------------------------------
# Valid_Loss: 1.1859, Valid_accuracy: 64.32%, Valid Recall: 27.29%, Valid Precision: 29.14%
# -------------------------------------------------------------------------------------------
#
# Epoch [26/100], Step [10/37], Loss: 0.8331, Acc: 68.83%
# Epoch [26/100], Step [20/37], Loss: 0.8412, Acc: 70.23%
# Epoch [26/100], Step [30/37], Loss: 0.9626, Acc: 69.06%
#
# -------------------------------------Result of Epoch 26------------------------------------
# Valid_Loss: 1.0297, Valid_accuracy: 68.75%, Valid Recall: 27.69%, Valid Precision: 29.63%
# -------------------------------------------------------------------------------------------
#
# Epoch [27/100], Step [10/37], Loss: 0.8243, Acc: 70.86%
# Epoch [27/100], Step [20/37], Loss: 0.7079, Acc: 69.22%
# Epoch [27/100], Step [30/37], Loss: 0.9876, Acc: 70.08%
#
# -------------------------------------Result of Epoch 27------------------------------------
# Valid_Loss: 1.1160, Valid_accuracy: 66.15%, Valid Recall: 26.64%, Valid Precision: 29.75%
# -------------------------------------------------------------------------------------------
#
# Epoch [28/100], Step [10/37], Loss: 0.8389, Acc: 68.36%
# Epoch [28/100], Step [20/37], Loss: 0.9756, Acc: 67.97%
# Epoch [28/100], Step [30/37], Loss: 0.9892, Acc: 70.62%
#
# -------------------------------------Result of Epoch 28------------------------------------
# Valid_Loss: 1.0250, Valid_accuracy: 69.70%, Valid Recall: 28.56%, Valid Precision: 30.00%
# -------------------------------------------------------------------------------------------
#
# Epoch [29/100], Step [10/37], Loss: 1.1646, Acc: 69.45%
# Epoch [29/100], Step [20/37], Loss: 0.9734, Acc: 70.78%
# Epoch [29/100], Step [30/37], Loss: 0.8871, Acc: 69.45%
#
# -------------------------------------Result of Epoch 29------------------------------------
# Valid_Loss: 0.9644, Valid_accuracy: 69.97%, Valid Recall: 28.93%, Valid Precision: 28.87%
# -------------------------------------------------------------------------------------------
#
# Epoch [30/100], Step [10/37], Loss: 0.7096, Acc: 74.61%
# Epoch [30/100], Step [20/37], Loss: 1.0176, Acc: 68.98%
# Epoch [30/100], Step [30/37], Loss: 0.7412, Acc: 67.81%
#
# -------------------------------------Result of Epoch 30------------------------------------
# Valid_Loss: 0.9243, Valid_accuracy: 71.79%, Valid Recall: 29.61%, Valid Precision: 30.75%
# -------------------------------------------------------------------------------------------
#
# Epoch [31/100], Step [10/37], Loss: 0.9432, Acc: 72.27%
# Epoch [31/100], Step [20/37], Loss: 0.8263, Acc: 71.41%
# Epoch [31/100], Step [30/37], Loss: 1.0485, Acc: 69.77%
#
# -------------------------------------Result of Epoch 31------------------------------------
# Valid_Loss: 1.0362, Valid_accuracy: 67.53%, Valid Recall: 27.53%, Valid Precision: 30.41%
# -------------------------------------------------------------------------------------------
#
# Epoch [32/100], Step [10/37], Loss: 1.0290, Acc: 72.73%
# Epoch [32/100], Step [20/37], Loss: 1.0523, Acc: 72.89%
# Epoch [32/100], Step [30/37], Loss: 0.8453, Acc: 71.48%
#
# -------------------------------------Result of Epoch 32------------------------------------
# Valid_Loss: 0.8768, Valid_accuracy: 73.35%, Valid Recall: 30.38%, Valid Precision: 31.49%
# -------------------------------------------------------------------------------------------
#
# Epoch [33/100], Step [10/37], Loss: 0.8658, Acc: 73.12%
# Epoch [33/100], Step [20/37], Loss: 0.9904, Acc: 72.03%
# Epoch [33/100], Step [30/37], Loss: 1.0117, Acc: 72.89%
#
# -------------------------------------Result of Epoch 33------------------------------------
# Valid_Loss: 0.9711, Valid_accuracy: 70.14%, Valid Recall: 29.22%, Valid Precision: 31.59%
# -------------------------------------------------------------------------------------------
#
# Epoch [34/100], Step [10/37], Loss: 0.8958, Acc: 72.89%
# Epoch [34/100], Step [20/37], Loss: 0.6343, Acc: 74.77%
# Epoch [34/100], Step [30/37], Loss: 0.8529, Acc: 71.17%
#
# -------------------------------------Result of Epoch 34------------------------------------
# Valid_Loss: 1.0100, Valid_accuracy: 68.58%, Valid Recall: 28.38%, Valid Precision: 28.97%
# -------------------------------------------------------------------------------------------
#
# Epoch [35/100], Step [10/37], Loss: 0.8725, Acc: 74.30%
# Epoch [35/100], Step [20/37], Loss: 0.7928, Acc: 71.88%
# Epoch [35/100], Step [30/37], Loss: 1.0478, Acc: 72.81%
#
# -------------------------------------Result of Epoch 35------------------------------------
# Valid_Loss: 0.8581, Valid_accuracy: 74.48%, Valid Recall: 30.91%, Valid Precision: 32.54%
# -------------------------------------------------------------------------------------------
#
# Epoch [36/100], Step [10/37], Loss: 0.9705, Acc: 71.09%
# Epoch [36/100], Step [20/37], Loss: 0.9121, Acc: 73.36%
# Epoch [36/100], Step [30/37], Loss: 0.8198, Acc: 72.50%
#
# -------------------------------------Result of Epoch 36------------------------------------
# Valid_Loss: 0.8357, Valid_accuracy: 75.26%, Valid Recall: 31.29%, Valid Precision: 32.10%
# -------------------------------------------------------------------------------------------
#
# Epoch [37/100], Step [10/37], Loss: 0.8472, Acc: 75.31%
# Epoch [37/100], Step [20/37], Loss: 0.7103, Acc: 74.92%
# Epoch [37/100], Step [30/37], Loss: 0.9969, Acc: 76.48%
#
# -------------------------------------Result of Epoch 37------------------------------------
# Valid_Loss: 0.9391, Valid_accuracy: 71.96%, Valid Recall: 28.98%, Valid Precision: 31.25%
# -------------------------------------------------------------------------------------------
#
# Epoch [38/100], Step [10/37], Loss: 0.6342, Acc: 74.53%
# Epoch [38/100], Step [20/37], Loss: 0.6685, Acc: 73.36%
# Epoch [38/100], Step [30/37], Loss: 0.8458, Acc: 71.80%
#
# -------------------------------------Result of Epoch 38------------------------------------
# Valid_Loss: 0.8801, Valid_accuracy: 73.61%, Valid Recall: 30.46%, Valid Precision: 32.02%
# -------------------------------------------------------------------------------------------
#
# Epoch [39/100], Step [10/37], Loss: 0.8394, Acc: 75.23%
# Epoch [39/100], Step [20/37], Loss: 0.6957, Acc: 76.09%
# Epoch [39/100], Step [30/37], Loss: 0.8289, Acc: 75.70%
#
# -------------------------------------Result of Epoch 39------------------------------------
# Valid_Loss: 0.9093, Valid_accuracy: 72.22%, Valid Recall: 30.00%, Valid Precision: 31.22%
# -------------------------------------------------------------------------------------------
#
# Epoch [40/100], Step [10/37], Loss: 0.7542, Acc: 75.16%
# Epoch [40/100], Step [20/37], Loss: 0.8687, Acc: 74.84%
# Epoch [40/100], Step [30/37], Loss: 0.8540, Acc: 74.77%
#
# -------------------------------------Result of Epoch 40------------------------------------
# Valid_Loss: 0.9133, Valid_accuracy: 72.14%, Valid Recall: 29.30%, Valid Precision: 31.05%
# -------------------------------------------------------------------------------------------
#
# Epoch [41/100], Step [10/37], Loss: 0.6962, Acc: 75.08%
# Epoch [41/100], Step [20/37], Loss: 0.6701, Acc: 75.16%
# Epoch [41/100], Step [30/37], Loss: 0.6745, Acc: 75.23%
#
# -------------------------------------Result of Epoch 41------------------------------------
# Valid_Loss: 1.0116, Valid_accuracy: 69.70%, Valid Recall: 28.86%, Valid Precision: 31.30%
# -------------------------------------------------------------------------------------------
#
# Epoch [42/100], Step [10/37], Loss: 0.7028, Acc: 77.27%
# Epoch [42/100], Step [20/37], Loss: 0.6747, Acc: 75.39%
# Epoch [42/100], Step [30/37], Loss: 0.8758, Acc: 72.27%
#
# -------------------------------------Result of Epoch 42------------------------------------
# Valid_Loss: 0.8288, Valid_accuracy: 74.83%, Valid Recall: 31.06%, Valid Precision: 31.23%
# -------------------------------------------------------------------------------------------
#
# Epoch [43/100], Step [10/37], Loss: 0.8597, Acc: 77.66%
# Epoch [43/100], Step [20/37], Loss: 0.7453, Acc: 73.59%
# Epoch [43/100], Step [30/37], Loss: 0.6635, Acc: 77.81%
#
# -------------------------------------Result of Epoch 43------------------------------------
# Valid_Loss: 0.8639, Valid_accuracy: 73.96%, Valid Recall: 31.54%, Valid Precision: 32.35%
# -------------------------------------------------------------------------------------------
#
# Epoch [44/100], Step [10/37], Loss: 0.7365, Acc: 75.39%
# Epoch [44/100], Step [20/37], Loss: 0.7304, Acc: 74.53%
# Epoch [44/100], Step [30/37], Loss: 0.7315, Acc: 76.17%
#
# -------------------------------------Result of Epoch 44------------------------------------
# Valid_Loss: 0.8239, Valid_accuracy: 74.31%, Valid Recall: 30.68%, Valid Precision: 33.21%
# -------------------------------------------------------------------------------------------
#
# Epoch [45/100], Step [10/37], Loss: 0.6328, Acc: 75.47%
# Epoch [45/100], Step [20/37], Loss: 1.0198, Acc: 75.86%
# Epoch [45/100], Step [30/37], Loss: 0.8152, Acc: 76.80%
#
# -------------------------------------Result of Epoch 45------------------------------------
# Valid_Loss: 0.7712, Valid_accuracy: 76.82%, Valid Recall: 32.13%, Valid Precision: 32.98%
# -------------------------------------------------------------------------------------------
#
# Epoch [46/100], Step [10/37], Loss: 0.6494, Acc: 78.98%
# Epoch [46/100], Step [20/37], Loss: 0.7342, Acc: 78.20%
# Epoch [46/100], Step [30/37], Loss: 0.7238, Acc: 77.19%
#
# -------------------------------------Result of Epoch 46------------------------------------
# Valid_Loss: 0.8228, Valid_accuracy: 75.87%, Valid Recall: 31.57%, Valid Precision: 33.35%
# -------------------------------------------------------------------------------------------
#
# Epoch [47/100], Step [10/37], Loss: 0.7996, Acc: 75.78%
# Epoch [47/100], Step [20/37], Loss: 0.6670, Acc: 77.89%
# Epoch [47/100], Step [30/37], Loss: 0.6886, Acc: 74.38%
#
# -------------------------------------Result of Epoch 47------------------------------------
# Valid_Loss: 0.8240, Valid_accuracy: 74.57%, Valid Recall: 30.96%, Valid Precision: 32.28%
# -------------------------------------------------------------------------------------------
#
# Epoch [48/100], Step [10/37], Loss: 0.6861, Acc: 78.83%
# Epoch [48/100], Step [20/37], Loss: 0.8137, Acc: 77.89%
# Epoch [48/100], Step [30/37], Loss: 0.7517, Acc: 78.52%
#
# -------------------------------------Result of Epoch 48------------------------------------
# Valid_Loss: 0.7266, Valid_accuracy: 77.26%, Valid Recall: 32.28%, Valid Precision: 33.59%
# -------------------------------------------------------------------------------------------
#
# Epoch [49/100], Step [10/37], Loss: 0.5680, Acc: 76.88%
# Epoch [49/100], Step [20/37], Loss: 0.6360, Acc: 76.09%
# Epoch [49/100], Step [30/37], Loss: 0.7134, Acc: 78.75%
#
# -------------------------------------Result of Epoch 49------------------------------------
# Valid_Loss: 0.8052, Valid_accuracy: 75.17%, Valid Recall: 30.90%, Valid Precision: 32.26%
# -------------------------------------------------------------------------------------------
#
# Epoch [50/100], Step [10/37], Loss: 0.5623, Acc: 76.80%
# Epoch [50/100], Step [20/37], Loss: 0.7686, Acc: 77.50%
# Epoch [50/100], Step [30/37], Loss: 0.6223, Acc: 76.17%
#
# -------------------------------------Result of Epoch 50------------------------------------
# Valid_Loss: 0.7877, Valid_accuracy: 75.61%, Valid Recall: 31.43%, Valid Precision: 34.06%
# -------------------------------------------------------------------------------------------
#
# Epoch [51/100], Step [10/37], Loss: 0.7741, Acc: 76.64%
# Epoch [51/100], Step [20/37], Loss: 0.7248, Acc: 76.33%
# Epoch [51/100], Step [30/37], Loss: 0.8291, Acc: 77.73%
#
# -------------------------------------Result of Epoch 51------------------------------------
# Valid_Loss: 0.7503, Valid_accuracy: 76.74%, Valid Recall: 31.72%, Valid Precision: 33.71%
# -------------------------------------------------------------------------------------------
#
# Epoch [52/100], Step [10/37], Loss: 0.6759, Acc: 79.45%
# Epoch [52/100], Step [20/37], Loss: 0.8072, Acc: 78.75%
# Epoch [52/100], Step [30/37], Loss: 0.6802, Acc: 77.81%
#
# -------------------------------------Result of Epoch 52------------------------------------
# Valid_Loss: 0.8863, Valid_accuracy: 72.83%, Valid Recall: 29.92%, Valid Precision: 33.11%
# -------------------------------------------------------------------------------------------
#
# Epoch [53/100], Step [10/37], Loss: 0.4985, Acc: 80.08%
# Epoch [53/100], Step [20/37], Loss: 0.8937, Acc: 78.44%
# Epoch [53/100], Step [30/37], Loss: 0.7378, Acc: 77.19%
#
# -------------------------------------Result of Epoch 53------------------------------------
# Valid_Loss: 0.7882, Valid_accuracy: 76.48%, Valid Recall: 32.06%, Valid Precision: 32.91%
# -------------------------------------------------------------------------------------------
#
# Epoch [54/100], Step [10/37], Loss: 0.6472, Acc: 80.47%
# Epoch [54/100], Step [20/37], Loss: 0.6362, Acc: 79.22%
# Epoch [54/100], Step [30/37], Loss: 0.8738, Acc: 80.78%
#
# -------------------------------------Result of Epoch 54------------------------------------
# Valid_Loss: 0.8004, Valid_accuracy: 75.17%, Valid Recall: 31.56%, Valid Precision: 32.68%
# -------------------------------------------------------------------------------------------
#
# Epoch [55/100], Step [10/37], Loss: 0.6767, Acc: 79.06%
# Epoch [55/100], Step [20/37], Loss: 0.7101, Acc: 76.95%
# Epoch [55/100], Step [30/37], Loss: 0.8056, Acc: 79.45%
#
# -------------------------------------Result of Epoch 55------------------------------------
# Valid_Loss: 0.7192, Valid_accuracy: 77.78%, Valid Recall: 31.55%, Valid Precision: 34.02%
# -------------------------------------------------------------------------------------------
#
# Epoch [56/100], Step [10/37], Loss: 0.6247, Acc: 78.75%
# Epoch [56/100], Step [20/37], Loss: 0.7826, Acc: 79.38%
# Epoch [56/100], Step [30/37], Loss: 0.6566, Acc: 80.16%
#
# -------------------------------------Result of Epoch 56------------------------------------
# Valid_Loss: 0.7655, Valid_accuracy: 77.52%, Valid Recall: 32.81%, Valid Precision: 33.71%
# -------------------------------------------------------------------------------------------
#
# Epoch [57/100], Step [10/37], Loss: 0.5032, Acc: 80.47%
# Epoch [57/100], Step [20/37], Loss: 0.7070, Acc: 77.19%
# Epoch [57/100], Step [30/37], Loss: 0.7764, Acc: 76.64%
#
# -------------------------------------Result of Epoch 57------------------------------------
# Valid_Loss: 0.7692, Valid_accuracy: 76.65%, Valid Recall: 32.11%, Valid Precision: 34.49%
# -------------------------------------------------------------------------------------------
#
# Epoch [58/100], Step [10/37], Loss: 0.6325, Acc: 80.62%
# Epoch [58/100], Step [20/37], Loss: 0.5845, Acc: 80.62%
# Epoch [58/100], Step [30/37], Loss: 0.7698, Acc: 77.42%
#
# -------------------------------------Result of Epoch 58------------------------------------
# Valid_Loss: 0.7313, Valid_accuracy: 78.91%, Valid Recall: 32.71%, Valid Precision: 34.23%
# -------------------------------------------------------------------------------------------
#
# Epoch [59/100], Step [10/37], Loss: 0.5718, Acc: 80.16%
# Epoch [59/100], Step [20/37], Loss: 0.8471, Acc: 78.75%
# Epoch [59/100], Step [30/37], Loss: 0.7080, Acc: 81.95%
#
# -------------------------------------Result of Epoch 59------------------------------------
# Valid_Loss: 0.7450, Valid_accuracy: 77.26%, Valid Recall: 31.91%, Valid Precision: 33.92%
# -------------------------------------------------------------------------------------------
#
# Epoch [60/100], Step [10/37], Loss: 0.5732, Acc: 80.47%
# Epoch [60/100], Step [20/37], Loss: 0.6956, Acc: 77.11%
# Epoch [60/100], Step [30/37], Loss: 0.7486, Acc: 78.83%
#
# -------------------------------------Result of Epoch 60------------------------------------
# Valid_Loss: 0.7003, Valid_accuracy: 79.08%, Valid Recall: 33.10%, Valid Precision: 33.71%
# -------------------------------------------------------------------------------------------
#
# Epoch [61/100], Step [10/37], Loss: 0.8737, Acc: 78.20%
# Epoch [61/100], Step [20/37], Loss: 0.5428, Acc: 80.62%
# Epoch [61/100], Step [30/37], Loss: 0.5870, Acc: 79.53%
#
# -------------------------------------Result of Epoch 61------------------------------------
# Valid_Loss: 0.6990, Valid_accuracy: 79.77%, Valid Recall: 33.48%, Valid Precision: 33.78%
# -------------------------------------------------------------------------------------------
#
# Epoch [62/100], Step [10/37], Loss: 0.4852, Acc: 80.00%
# Epoch [62/100], Step [20/37], Loss: 0.4722, Acc: 80.70%
# Epoch [62/100], Step [30/37], Loss: 0.6150, Acc: 79.61%
#
# -------------------------------------Result of Epoch 62------------------------------------
# Valid_Loss: 0.6844, Valid_accuracy: 79.25%, Valid Recall: 33.38%, Valid Precision: 33.78%
# -------------------------------------------------------------------------------------------
#
# Epoch [63/100], Step [10/37], Loss: 0.4130, Acc: 80.31%
# Epoch [63/100], Step [20/37], Loss: 0.6128, Acc: 82.66%
# Epoch [63/100], Step [30/37], Loss: 0.5846, Acc: 80.16%
#
# -------------------------------------Result of Epoch 63------------------------------------
# Valid_Loss: 0.6899, Valid_accuracy: 79.69%, Valid Recall: 33.25%, Valid Precision: 34.25%
# -------------------------------------------------------------------------------------------
#
# Epoch [64/100], Step [10/37], Loss: 0.6008, Acc: 82.03%
# Epoch [64/100], Step [20/37], Loss: 0.5427, Acc: 82.19%
# Epoch [64/100], Step [30/37], Loss: 0.6198, Acc: 80.16%
#
# -------------------------------------Result of Epoch 64------------------------------------
# Valid_Loss: 0.7044, Valid_accuracy: 79.51%, Valid Recall: 32.68%, Valid Precision: 34.28%
# -------------------------------------------------------------------------------------------
#
# Epoch [65/100], Step [10/37], Loss: 0.5695, Acc: 78.83%
# Epoch [65/100], Step [20/37], Loss: 0.4969, Acc: 79.53%
# Epoch [65/100], Step [30/37], Loss: 0.7558, Acc: 80.39%
#
# -------------------------------------Result of Epoch 65------------------------------------
# Valid_Loss: 0.6470, Valid_accuracy: 81.60%, Valid Recall: 34.43%, Valid Precision: 34.89%
# -------------------------------------------------------------------------------------------
#
# Epoch [66/100], Step [10/37], Loss: 0.5705, Acc: 80.55%
# Epoch [66/100], Step [20/37], Loss: 0.9895, Acc: 81.41%
# Epoch [66/100], Step [30/37], Loss: 0.6244, Acc: 82.11%
#
# -------------------------------------Result of Epoch 66------------------------------------
# Valid_Loss: 0.7310, Valid_accuracy: 78.82%, Valid Recall: 33.29%, Valid Precision: 34.18%
# -------------------------------------------------------------------------------------------
#
# Epoch [67/100], Step [10/37], Loss: 0.5626, Acc: 81.41%
# Epoch [67/100], Step [20/37], Loss: 0.5050, Acc: 81.02%
# Epoch [67/100], Step [30/37], Loss: 0.8482, Acc: 83.75%
#
# -------------------------------------Result of Epoch 67------------------------------------
# Valid_Loss: 0.7810, Valid_accuracy: 77.08%, Valid Recall: 31.82%, Valid Precision: 34.90%
# -------------------------------------------------------------------------------------------
#
# Epoch [68/100], Step [10/37], Loss: 0.7022, Acc: 78.36%
# Epoch [68/100], Step [20/37], Loss: 0.6728, Acc: 78.75%
# Epoch [68/100], Step [30/37], Loss: 0.4656, Acc: 80.86%
#
# -------------------------------------Result of Epoch 68------------------------------------
# Valid_Loss: 0.7337, Valid_accuracy: 78.47%, Valid Recall: 33.11%, Valid Precision: 33.89%
# -------------------------------------------------------------------------------------------
#
# Epoch [69/100], Step [10/37], Loss: 0.5789, Acc: 80.31%
# Epoch [69/100], Step [20/37], Loss: 0.3877, Acc: 83.44%
# Epoch [69/100], Step [30/37], Loss: 0.4494, Acc: 81.56%
#
# -------------------------------------Result of Epoch 69------------------------------------
# Valid_Loss: 0.8049, Valid_accuracy: 75.35%, Valid Recall: 31.39%, Valid Precision: 33.84%
# -------------------------------------------------------------------------------------------
#
# Epoch [70/100], Step [10/37], Loss: 0.6564, Acc: 82.81%
# Epoch [70/100], Step [20/37], Loss: 0.6138, Acc: 80.16%
# Epoch [70/100], Step [30/37], Loss: 0.6395, Acc: 77.27%
#
# -------------------------------------Result of Epoch 70------------------------------------
# Valid_Loss: 0.6857, Valid_accuracy: 79.34%, Valid Recall: 32.64%, Valid Precision: 34.38%
# -------------------------------------------------------------------------------------------
#
# Epoch [71/100], Step [10/37], Loss: 0.4681, Acc: 81.95%
# Epoch [71/100], Step [20/37], Loss: 0.6284, Acc: 82.11%
# Epoch [71/100], Step [30/37], Loss: 0.4468, Acc: 83.28%
#
# -------------------------------------Result of Epoch 71------------------------------------
# Valid_Loss: 0.6376, Valid_accuracy: 81.86%, Valid Recall: 34.81%, Valid Precision: 35.43%
# -------------------------------------------------------------------------------------------
#
# Epoch [72/100], Step [10/37], Loss: 0.5202, Acc: 82.66%
# Epoch [72/100], Step [20/37], Loss: 0.6209, Acc: 80.47%
# Epoch [72/100], Step [30/37], Loss: 0.5873, Acc: 80.86%
#
# -------------------------------------Result of Epoch 72------------------------------------
# Valid_Loss: 0.7054, Valid_accuracy: 78.99%, Valid Recall: 32.44%, Valid Precision: 35.49%
# -------------------------------------------------------------------------------------------
#
# Epoch [73/100], Step [10/37], Loss: 0.5545, Acc: 82.73%
# Epoch [73/100], Step [20/37], Loss: 0.6022, Acc: 82.97%
# Epoch [73/100], Step [30/37], Loss: 0.5201, Acc: 82.11%
#
# -------------------------------------Result of Epoch 73------------------------------------
# Valid_Loss: 0.6834, Valid_accuracy: 79.25%, Valid Recall: 33.07%, Valid Precision: 34.43%
# -------------------------------------------------------------------------------------------
#
# Epoch [74/100], Step [10/37], Loss: 0.5806, Acc: 82.73%
# Epoch [74/100], Step [20/37], Loss: 0.4919, Acc: 82.66%
# Epoch [74/100], Step [30/37], Loss: 0.5635, Acc: 82.42%
#
# -------------------------------------Result of Epoch 74------------------------------------
# Valid_Loss: 0.7130, Valid_accuracy: 78.82%, Valid Recall: 32.79%, Valid Precision: 34.23%
# -------------------------------------------------------------------------------------------
#
# Epoch [75/100], Step [10/37], Loss: 0.7296, Acc: 83.44%
# Epoch [75/100], Step [20/37], Loss: 0.4689, Acc: 85.16%
# Epoch [75/100], Step [30/37], Loss: 0.3467, Acc: 83.67%
#
# -------------------------------------Result of Epoch 75------------------------------------
# Valid_Loss: 0.6391, Valid_accuracy: 82.20%, Valid Recall: 34.42%, Valid Precision: 33.95%
# -------------------------------------------------------------------------------------------
#
# Epoch [76/100], Step [10/37], Loss: 0.3952, Acc: 85.00%
# Epoch [76/100], Step [20/37], Loss: 0.4880, Acc: 82.66%
# Epoch [76/100], Step [30/37], Loss: 0.4610, Acc: 81.56%
#
# -------------------------------------Result of Epoch 76------------------------------------
# Valid_Loss: 0.7376, Valid_accuracy: 78.56%, Valid Recall: 33.12%, Valid Precision: 33.71%
# -------------------------------------------------------------------------------------------
#
# Epoch [77/100], Step [10/37], Loss: 0.4862, Acc: 80.86%
# Epoch [77/100], Step [20/37], Loss: 0.6854, Acc: 81.17%
# Epoch [77/100], Step [30/37], Loss: 0.5960, Acc: 82.11%
#
# -------------------------------------Result of Epoch 77------------------------------------
# Valid_Loss: 0.6825, Valid_accuracy: 78.21%, Valid Recall: 32.31%, Valid Precision: 34.13%
# -------------------------------------------------------------------------------------------
#
# Epoch [78/100], Step [10/37], Loss: 0.3369, Acc: 83.91%
# Epoch [78/100], Step [20/37], Loss: 0.6039, Acc: 83.59%
# Epoch [78/100], Step [30/37], Loss: 0.6709, Acc: 81.09%
#
# -------------------------------------Result of Epoch 78------------------------------------
# Valid_Loss: 0.7110, Valid_accuracy: 78.04%, Valid Recall: 32.33%, Valid Precision: 34.91%
# -------------------------------------------------------------------------------------------
#
# Epoch [79/100], Step [10/37], Loss: 0.5243, Acc: 83.12%
# Epoch [79/100], Step [20/37], Loss: 0.3280, Acc: 82.73%
# Epoch [79/100], Step [30/37], Loss: 0.5249, Acc: 82.81%
#
# -------------------------------------Result of Epoch 79------------------------------------
# Valid_Loss: 0.7060, Valid_accuracy: 80.56%, Valid Recall: 34.14%, Valid Precision: 34.14%
# -------------------------------------------------------------------------------------------
#
# Epoch [80/100], Step [10/37], Loss: 0.5374, Acc: 82.66%
# Epoch [80/100], Step [20/37], Loss: 0.7168, Acc: 83.59%
# Epoch [80/100], Step [30/37], Loss: 0.6943, Acc: 81.33%
#
# -------------------------------------Result of Epoch 80------------------------------------
# Valid_Loss: 0.7607, Valid_accuracy: 78.04%, Valid Recall: 33.90%, Valid Precision: 33.31%
# -------------------------------------------------------------------------------------------
#
# Epoch [81/100], Step [10/37], Loss: 0.5530, Acc: 83.75%
# Epoch [81/100], Step [20/37], Loss: 0.4786, Acc: 85.62%
# Epoch [81/100], Step [30/37], Loss: 0.5920, Acc: 83.05%
#
# -------------------------------------Result of Epoch 81------------------------------------
# Valid_Loss: 0.7196, Valid_accuracy: 79.25%, Valid Recall: 33.81%, Valid Precision: 34.74%
# -------------------------------------------------------------------------------------------
#
# Epoch [82/100], Step [10/37], Loss: 0.4300, Acc: 83.44%
# Epoch [82/100], Step [20/37], Loss: 0.3918, Acc: 85.31%
# Epoch [82/100], Step [30/37], Loss: 0.5454, Acc: 80.70%
#
# -------------------------------------Result of Epoch 82------------------------------------
# Valid_Loss: 0.6792, Valid_accuracy: 79.95%, Valid Recall: 33.61%, Valid Precision: 35.14%
# -------------------------------------------------------------------------------------------
#
# Epoch [83/100], Step [10/37], Loss: 0.3717, Acc: 85.16%
# Epoch [83/100], Step [20/37], Loss: 0.4380, Acc: 84.92%
# Epoch [83/100], Step [30/37], Loss: 0.4849, Acc: 81.41%
#
# -------------------------------------Result of Epoch 83------------------------------------
# Valid_Loss: 0.6070, Valid_accuracy: 82.12%, Valid Recall: 34.87%, Valid Precision: 34.96%
# -------------------------------------------------------------------------------------------
#
# Epoch [84/100], Step [10/37], Loss: 0.7314, Acc: 83.36%
# Epoch [84/100], Step [20/37], Loss: 0.3658, Acc: 82.89%
# Epoch [84/100], Step [30/37], Loss: 0.4624, Acc: 82.89%
#
# -------------------------------------Result of Epoch 84------------------------------------
# Valid_Loss: 0.6230, Valid_accuracy: 82.29%, Valid Recall: 34.64%, Valid Precision: 35.11%
# -------------------------------------------------------------------------------------------
#
# Epoch [85/100], Step [10/37], Loss: 0.6724, Acc: 86.25%
# Epoch [85/100], Step [20/37], Loss: 0.4608, Acc: 85.62%
# Epoch [85/100], Step [30/37], Loss: 0.5307, Acc: 83.12%
#
# -------------------------------------Result of Epoch 85------------------------------------
# Valid_Loss: 0.6360, Valid_accuracy: 81.86%, Valid Recall: 34.43%, Valid Precision: 35.57%
# -------------------------------------------------------------------------------------------
#
# Epoch [86/100], Step [10/37], Loss: 0.4892, Acc: 85.70%
# Epoch [86/100], Step [20/37], Loss: 0.4797, Acc: 86.09%
# Epoch [86/100], Step [30/37], Loss: 0.4994, Acc: 82.50%
#
# -------------------------------------Result of Epoch 86------------------------------------
# Valid_Loss: 0.6289, Valid_accuracy: 81.94%, Valid Recall: 34.33%, Valid Precision: 34.89%
# -------------------------------------------------------------------------------------------
#
# Epoch [87/100], Step [10/37], Loss: 0.4621, Acc: 82.89%
# Epoch [87/100], Step [20/37], Loss: 0.5949, Acc: 84.69%
# Epoch [87/100], Step [30/37], Loss: 0.7186, Acc: 83.75%
#
# -------------------------------------Result of Epoch 87------------------------------------
# Valid_Loss: 0.6391, Valid_accuracy: 81.51%, Valid Recall: 34.19%, Valid Precision: 34.80%
# -------------------------------------------------------------------------------------------
#
# Epoch [88/100], Step [10/37], Loss: 0.4975, Acc: 83.67%
# Epoch [88/100], Step [20/37], Loss: 0.4437, Acc: 86.09%
# Epoch [88/100], Step [30/37], Loss: 0.6379, Acc: 84.53%
#
# -------------------------------------Result of Epoch 88------------------------------------
# Valid_Loss: 0.6979, Valid_accuracy: 79.25%, Valid Recall: 33.09%, Valid Precision: 34.88%
# -------------------------------------------------------------------------------------------
#
# Epoch [89/100], Step [10/37], Loss: 0.5287, Acc: 83.98%
# Epoch [89/100], Step [20/37], Loss: 0.3675, Acc: 84.77%
# Epoch [89/100], Step [30/37], Loss: 0.5825, Acc: 84.92%
#
# -------------------------------------Result of Epoch 89------------------------------------
# Valid_Loss: 0.6356, Valid_accuracy: 82.12%, Valid Recall: 34.78%, Valid Precision: 34.93%
# -------------------------------------------------------------------------------------------
#
# Epoch [90/100], Step [10/37], Loss: 0.6757, Acc: 85.86%
# Epoch [90/100], Step [20/37], Loss: 0.3544, Acc: 85.00%
# Epoch [90/100], Step [30/37], Loss: 0.5506, Acc: 84.77%
#
# -------------------------------------Result of Epoch 90------------------------------------
# Valid_Loss: 0.6575, Valid_accuracy: 80.21%, Valid Recall: 33.16%, Valid Precision: 35.74%
# -------------------------------------------------------------------------------------------
#
# Epoch [91/100], Step [10/37], Loss: 0.3975, Acc: 83.98%
# Epoch [91/100], Step [20/37], Loss: 0.4276, Acc: 83.44%
# Epoch [91/100], Step [30/37], Loss: 0.7234, Acc: 83.75%
#
# -------------------------------------Result of Epoch 91------------------------------------
# Valid_Loss: 0.6565, Valid_accuracy: 81.60%, Valid Recall: 34.59%, Valid Precision: 35.60%
# -------------------------------------------------------------------------------------------
#
# Epoch [92/100], Step [10/37], Loss: 0.5064, Acc: 85.31%
# Epoch [92/100], Step [20/37], Loss: 0.5261, Acc: 83.83%
# Epoch [92/100], Step [30/37], Loss: 0.4997, Acc: 86.48%
#
# -------------------------------------Result of Epoch 92------------------------------------
# Valid_Loss: 0.6022, Valid_accuracy: 82.03%, Valid Recall: 33.63%, Valid Precision: 35.41%
# -------------------------------------------------------------------------------------------
#
# Epoch [93/100], Step [10/37], Loss: 0.3002, Acc: 84.53%
# Epoch [93/100], Step [20/37], Loss: 0.6442, Acc: 85.70%
# Epoch [93/100], Step [30/37], Loss: 0.3179, Acc: 86.17%
#
# -------------------------------------Result of Epoch 93------------------------------------
# Valid_Loss: 0.6876, Valid_accuracy: 80.73%, Valid Recall: 33.69%, Valid Precision: 35.18%
# -------------------------------------------------------------------------------------------
#
# Epoch [94/100], Step [10/37], Loss: 0.4884, Acc: 84.53%
# Epoch [94/100], Step [20/37], Loss: 0.6078, Acc: 84.92%
# Epoch [94/100], Step [30/37], Loss: 0.4629, Acc: 83.44%
#
# -------------------------------------Result of Epoch 94------------------------------------
# Valid_Loss: 0.6099, Valid_accuracy: 82.55%, Valid Recall: 34.76%, Valid Precision: 35.17%
# -------------------------------------------------------------------------------------------
#
# Epoch [95/100], Step [10/37], Loss: 0.3741, Acc: 85.39%
# Epoch [95/100], Step [20/37], Loss: 0.4555, Acc: 86.72%
# Epoch [95/100], Step [30/37], Loss: 0.5392, Acc: 82.58%
#
# -------------------------------------Result of Epoch 95------------------------------------
# Valid_Loss: 0.7376, Valid_accuracy: 78.65%, Valid Recall: 32.91%, Valid Precision: 33.95%
# -------------------------------------------------------------------------------------------
#
# Epoch [96/100], Step [10/37], Loss: 0.5547, Acc: 84.06%
# Epoch [96/100], Step [20/37], Loss: 0.5064, Acc: 83.91%
# Epoch [96/100], Step [30/37], Loss: 0.6251, Acc: 84.69%
#
# -------------------------------------Result of Epoch 96------------------------------------
# Valid_Loss: 0.6101, Valid_accuracy: 82.55%, Valid Recall: 35.11%, Valid Precision: 35.47%
# -------------------------------------------------------------------------------------------
#
# Epoch [97/100], Step [10/37], Loss: 0.3459, Acc: 86.25%
# Epoch [97/100], Step [20/37], Loss: 0.3675, Acc: 86.17%
# Epoch [97/100], Step [30/37], Loss: 0.5302, Acc: 84.22%
#
# -------------------------------------Result of Epoch 97------------------------------------
# Valid_Loss: 0.6775, Valid_accuracy: 80.30%, Valid Recall: 34.02%, Valid Precision: 34.72%
# -------------------------------------------------------------------------------------------
#
# Epoch [98/100], Step [10/37], Loss: 0.6101, Acc: 86.09%
# Epoch [98/100], Step [20/37], Loss: 0.3331, Acc: 85.08%
# Epoch [98/100], Step [30/37], Loss: 0.4790, Acc: 84.84%
#
# -------------------------------------Result of Epoch 98------------------------------------
# Valid_Loss: 0.6818, Valid_accuracy: 80.21%, Valid Recall: 33.44%, Valid Precision: 34.39%
# -------------------------------------------------------------------------------------------
#
# Epoch [99/100], Step [10/37], Loss: 0.5436, Acc: 84.92%
# Epoch [99/100], Step [20/37], Loss: 0.3866, Acc: 86.02%
# Epoch [99/100], Step [30/37], Loss: 0.3502, Acc: 86.02%
#
# -------------------------------------Result of Epoch 99------------------------------------
# Valid_Loss: 0.6146, Valid_accuracy: 81.68%, Valid Recall: 34.81%, Valid Precision: 34.24%
# -------------------------------------------------------------------------------------------
#
# Epoch [100/100], Step [10/37], Loss: 0.5052, Acc: 84.69%
# Epoch [100/100], Step [20/37], Loss: 0.3392, Acc: 84.38%
# Epoch [100/100], Step [30/37], Loss: 0.4725, Acc: 85.86%

# %%
print(f'------------------------------------Learning complete-----------------------------------\n')
avr_loss, test_acc, test_rec, test_prec = valid_map(test_loader)
rec = sum(test_rec.compute())/len(list(label_map))
prec = sum(test_prec.compute())/len(list(label_map))
print(f'\n-------------------------------------Result of Testing------------------------------------')
print(f'Valid_Loss: {avr_loss:.4f}, Valid_accuracy: {test_acc:.2f*2}%, Valid Recall: {rec.item():.2f*2}%, Valid Precision: {prec.item():.2f}%')
print(f'-------------------------------------------------------------------------------------------\n')

# %%
plt.plot(range(len(list_loss)), list_loss)
plt.ylabel('Loss')
plt.show()

# %%
recall_class = {classname: val.item()
                for classname, val in zip(label_map, test_rec.compute())}
precision_class = {classname: val.item()
                   for classname, val in zip(label_map, test_prec.compute())}
metrics_per_class = {
    "recall": recall_class, "precision": precision_class}

fig, axes = plt.subplots(1, 2, figsize=(25, 5))
for (metricName, mVal), ax in zip(metrics_per_class.items(), axes):
    plt.sca(ax)
    plt.bar(mVal.keys(), mVal.values())
    plt.ylabel(metricName)
    plt.xticks(rotation=90)
    plt.grid(axis='y')
    plt.yticks(ticks=np.arange(0, 1.01, 0.05))
plt.show()
